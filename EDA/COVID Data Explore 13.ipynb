# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Goal: I want to calculate mortality rates by ethnicity and then compare this to the correlation between overall mortality and several sociodemographic factors.

# %%
df = pd.read_csv('COVID_Cases_Restricted_Detailed_10312020.csv')

# %%
df.head()
# Out:
#   race_ethnicity_combined             current_status cdc_report_dt   sex  \
# 0     White, Non-Hispanic  Laboratory-confirmed case    2020-10-01  Male
# 1     White, Non-Hispanic  Laboratory-confirmed case    2020-08-23  Male
# 2     White, Non-Hispanic  Laboratory-confirmed case    2020-10-01  Male
# 3     White, Non-Hispanic  Laboratory-confirmed case    2020-10-01  Male
# 4     White, Non-Hispanic  Laboratory-confirmed case    2020-09-18  Male
#
#      onset_dt pos_spec_dt  hosp_yn   icu_yn death_yn hc_work_yn   pna_yn  \
# 0  2020-08-26         NaN  Missing  Missing  Missing    Missing  Missing
# 1  2020-07-07         NaN  Missing  Missing  Missing    Missing  Missing
# 2  2020-09-02         NaN  Missing  Missing  Missing    Missing  Missing
# 3  2020-09-01         NaN  Missing  Missing  Missing    Missing  Missing
# 4  2020-09-01         NaN  Missing  Missing  Missing    Missing  Missing
#
#   abxchest_yn acuterespdistress_yn mechvent_yn fever_yn sfever_yn chills_yn  \
# 0     Missing              Missing     Missing  Missing   Missing   Missing
# 1     Missing              Missing     Missing  Missing   Missing   Missing
# 2     Missing              Missing     Missing  Missing   Missing   Missing
# 3     Missing              Missing     Missing  Missing   Missing   Missing
# 4     Missing              Missing     Missing  Missing   Missing   Missing
#
#   myalgia_yn runnose_yn sthroat_yn cough_yn   sob_yn nauseavomit_yn  \
# 0    Missing    Missing    Missing  Missing  Missing        Missing
# 1    Missing    Missing    Missing  Missing  Missing        Missing
# 2    Missing    Missing    Missing  Missing  Missing        Missing
# 3    Missing    Missing    Missing  Missing  Missing        Missing
# 4    Missing    Missing    Missing  Missing  Missing        Missing
#
#   headache_yn abdom_yn diarrhea_yn medcond_yn  county_fips_code res_county  \
# 0     Missing  Missing     Missing    Missing           31001.0      ADAMS
# 1     Missing  Missing     Missing    Missing           31001.0      ADAMS
# 2     Missing  Missing     Missing    Missing           31001.0      ADAMS
# 3     Missing  Missing     Missing    Missing           31001.0      ADAMS
# 4     Missing  Missing     Missing    Missing           31001.0      ADAMS
#
#   res_state      age_group
# 0        NE  10 - 19 Years
# 1        NE  10 - 19 Years
# 2        NE  10 - 19 Years
# 3        NE  10 - 19 Years
# 4        NE  10 - 19 Years

# %%
#Drop 'Missing' and 'Unknown' from death_yn so that there are only cases where death = Yes or No. Drop 'Unknown' cases from race_ethnicity
df_oct = df[(df.death_yn != 'Missing') & (df.death_yn != 'Unknown') & (df.race_ethnicity_combined != 'Unknown')]
df_oct['race_ethnicity_combined'].value_counts()
# Out:
# White, Non-Hispanic                                     923189
# Hispanic/Latino                                         476914
# Black, Non-Hispanic                                     316076
# Multiple/Other, Non-Hispanic                             77836
# Asian, Non-Hispanic                                      53659
# American Indian/Alaska Native, Non-Hispanic               9689
# Native Hawaiian/Other Pacific Islander, Non-Hispanic      4964
# Name: race_ethnicity_combined, dtype: int64

# %%
#Abbreviate ethnicity_race names for simplicity
df_oct = df_oct.replace({'race_ethnicity_combined' : { 'White, Non-Hispanic' : 'W', 
                                                      'Hispanic/Latino' : 'H/L', 
                                                      'Black, Non-Hispanic' : 'B', 
                                                      'Multiple/Other, Non-Hispanic ' : 'M/O', 
                                                      'Asian, Non-Hispanic' : 'A', 
                                                      'American Indian/Alaska Native, Non-Hispanic' : 'AI/AN', 
                                                      'Native Hawaiian/Other Pacific Islander, Non-Hispanic' : 'NH/OPI'}})
df_oct['race_ethnicity_combined'].value_counts()
# Out:
# W         923189
# H/L       476914
# B         316076
# M/O        77836
# A          53659
# AI/AN       9689
# NH/OPI      4964
# Name: race_ethnicity_combined, dtype: int64

# %%
#Determine % Mortality Rate by Ethnicity
W = df_oct[df_oct.race_ethnicity_combined == "W"]
W_Mortality_Rate = float(len(W[W.death_yn == 'Yes'])) / len(W)
H = df_oct[df_oct.race_ethnicity_combined == "H/L"]
H_Mortality_Rate = float(len(H[H.death_yn == 'Yes'])) / len(H)
B = df_oct[df_oct.race_ethnicity_combined == "B"]
B_Mortality_Rate = float(len(B[B.death_yn == 'Yes'])) / len(B)
M = df_oct[df_oct.race_ethnicity_combined == "M/O"]
M_Mortality_Rate = float(len(M[M.death_yn == 'Yes'])) / len(M)
A = df_oct[df_oct.race_ethnicity_combined == "A"]
A_Mortality_Rate = float(len(A[A.death_yn == 'Yes'])) / len(A)
AI = df_oct[df_oct.race_ethnicity_combined == "AI/AN"]
AI_Mortality_Rate = float(len(AI[AI.death_yn == 'Yes'])) / len(AI)
NH = df_oct[df_oct.race_ethnicity_combined == "NH/OPI"]
NH_Mortality_Rate = float(len(NH[NH.death_yn == 'Yes'])) / len(NH)

df_Mrate = pd.DataFrame([('W', W_Mortality_Rate*100), 
                         ('H/L', H_Mortality_Rate*100), 
                         ('B', B_Mortality_Rate*100), 
                         ('M/O', M_Mortality_Rate*100), 
                         ('A' , A_Mortality_Rate*100), 
                         ('AI/AN', AI_Mortality_Rate*100), 
                         ('NH/OPI', NH_Mortality_Rate*100)],
                  columns=['Ethnicity', '% Mortality Rate'])
df_Mrate
# Out:
#   Ethnicity  % Mortality Rate
# 0         W          7.716188
# 1       H/L          4.393035
# 2         B          8.279338
# 3       M/O          6.407061
# 4         A          9.129876
# 5     AI/AN          8.772835
# 6    NH/OPI          2.356970

# %% [markdown]
# Next step is to attach select sociodemographic factors to the CDC data so that the correlation with mortality can easily be calculated. The FIPS will be used to add the information by county.

# %%
df_oct.rename(columns={"county_fips_code": "FIPS"}, inplace=True)
print(df_oct.columns)
# Out:
# Index(['race_ethnicity_combined', 'current_status', 'cdc_report_dt', 'sex',
#        'onset_dt', 'pos_spec_dt', 'hosp_yn', 'icu_yn', 'death_yn',
#        'hc_work_yn', 'pna_yn', 'abxchest_yn', 'acuterespdistress_yn',
#        'mechvent_yn', 'fever_yn', 'sfever_yn', 'chills_yn', 'myalgia_yn',
#        'runnose_yn', 'sthroat_yn', 'cough_yn', 'sob_yn', 'nauseavomit_yn',
#        'headache_yn', 'abdom_yn', 'diarrhea_yn', 'medcond_yn', 'FIPS',
#        'res_county', 'res_state', 'age_group'],
#       dtype='object')

# %%
#Load the table with sociodemographic data by county and rename the columns I want to use for better readability
df_health = pd.read_excel('Health Factors by County 2020 County Health Rankings Rows.xls', sheet_name='Ranked Measure Data')
df_health.rename(columns={'Adult obesity - % Adults with Obesity':'% Obesity'
                          , 'Adult smoking - % Smokers':'% Smokers', 
                          'Physical inactivity - % Physically Inactive':'% Phys. Inactive', 
                          'Uninsured - % Uninsured': '% Uninsured', 
                          'High school graduation - High School Graduation Rate':'% High School', 
                          'Some college - % Some College':'% Some College', 
                          'Unemployment - % Unemployed':'% Unemployed'}, inplace=True)
pd.set_option('display.max_columns', None)
df_health.head(3)
# Out:
#    FIPS    State   County  Premature death - Deaths  \
# 0  1000  Alabama      NaN                   81791.0
# 1  1001  Alabama  Autauga                     791.0
# 2  1003  Alabama  Baldwin                    2967.0
#
#    Premature death - Years of Potential Life Lost Rate  \
# 0                                        9942.794666
# 1                                        8128.591190
# 2                                        7354.122530
#
#    Premature death - 95% CI - Low  Premature death - 95% CI - High  \
# 0                     9840.535949                     10045.053384
# 1                     7283.340731                      8973.841649
# 2                     6918.554270                      7789.690790
#
#    Premature death - Quartile  Premature death - YPLL Rate (AIAN)  \
# 0                         NaN                                 NaN
# 1                         1.0                                 NaN
# 2                         1.0                                 NaN
#
#    Premature death - YPLL Rate (AIAN) 95% CI - Low  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
#
#    Premature death - YPLL Rate (AIAN) 95% CI - High  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
#
#    Premature death - YPLL Rate (Asian)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
#
#    Premature death - YPLL Rate (Asian) 95% CI - Low  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
#
#    Premature death - YPLL Rate (Asian) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Premature death - YPLL Rate (Black)  \
# 0                                  NaN
# 1                         10201.389930
# 2                          9890.505276
#
#    Premature death - YPLL Rate (Black) 95% CI - Low  \
# 0                                               NaN
# 1                                       8123.819140
# 2                                       8388.547243
#
#    Premature death - YPLL Rate (Black) 95% CI - High  \
# 0                                                NaN
# 1                                       12278.960720
# 2                                       11392.463309
#
#    Premature death - YPLL Rate (Hispanic)  \
# 0                                     NaN
# 1                                     NaN
# 2                             3570.475264
#
#    Premature death - YPLL Rate (Hispanic) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                        2372.554883
#
#    Premature death - YPLL Rate (Hispanic) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                        5160.330872
#
#    Premature death - YPLL Rate (White)  \
# 0                                  NaN
# 1                          7885.665370
# 2                          7435.761186
#
#    Premature death - YPLL Rate (White) 95% CI - Low  \
# 0                                               NaN
# 1                                       6923.632080
# 2                                       6940.450728
#
#    Premature death - YPLL Rate (White) 95% CI - High  \
# 0                                                NaN
# 1                                        8847.698659
# 2                                        7931.071645
#
#    Poor or fair health - % Fair or Poor Health  \
# 0                                    22.028703
# 1                                    20.882987
# 2                                    17.509134
#
#    Poor or fair health - 95% CI - Low  Poor or fair health - 95% CI - High  \
# 0                           20.743429                            23.370130
# 1                           20.252255                            21.499178
# 2                           17.024152                            18.017701
#
#    Poor or fair health - Quartile  \
# 0                             NaN
# 1                             1.0
# 2                             1.0
#
#    Poor physical health days - Average Number of Physically Unhealthy Days  \
# 0                                           4.918052
# 1                                           4.743889
# 2                                           4.224519
#
#    Poor physical health days - 95% CI - Low  \
# 0                                  4.599799
# 1                                  4.564332
# 2                                  4.075200
#
#    Poor physical health days - 95% CI - High  \
# 0                                   5.236304
# 1                                   4.916272
# 2                                   4.381421
#
#    Poor physical health days - Quartile  \
# 0                                   NaN
# 1                                   2.0
# 2                                   1.0
#
#    Poor mental health days - Average Number of Mentally Unhealthy Days  \
# 0                                           4.939753
# 1                                           4.654031
# 2                                           4.304056
#
#    Poor mental health days - 95% CI - Low  \
# 0                                4.595322
# 1                                4.464817
# 2                                4.133483
#
#    Poor mental health days - 95% CI - High  \
# 0                                 5.284183
# 1                                 4.839471
# 2                                 4.468240
#
#    Poor mental health days - Quartile Low birthweight - Unreliable  \
# 0                                 NaN                          NaN
# 1                                 1.0                          NaN
# 2                                 1.0                          NaN
#
#    Low birthweight - % Low Birthweight  Low birthweight - 95% CI - Low  \
# 0                            10.254871                       10.162161
# 1                             8.619529                        7.795389
# 2                             8.345003                        7.912530
#
#    Low birthweight - 95% CI - High  Low birthweight - Quartile  \
# 0                        10.347580                         NaN
# 1                         9.443668                         1.0
# 2                         8.777476                         1.0
#
#    Low birthweight - % LBW (AIAN)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
#
#    Low birthweight - % LBW (AIAN) 95% CI - Low  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#    Low birthweight - % LBW (AIAN) 95% CI - High  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
#    Low birthweight - % LBW (Asian)  \
# 0                              NaN
# 1                              NaN
# 2                          10.9375
#
#    Low birthweight - % LBW (Asian) 95% CI - Low  \
# 0                                           NaN
# 1                                           NaN
# 2                                           6.5
#
#    Low birthweight - % LBW (Asian) 95% CI - High  \
# 0                                            NaN
# 1                                            NaN
# 2                                           15.4
#
#    Low birthweight - % LBW (Black)  \
# 0                              NaN
# 1                        13.505155
# 2                        15.002758
#
#    Low birthweight - % LBW (Black) 95% CI - Low  \
# 0                                           NaN
# 1                                          11.4
# 2                                          13.4
#
#    Low birthweight - % LBW (Black) 95% CI - High  \
# 0                                            NaN
# 1                                           15.7
# 2                                           16.6
#
#    Low birthweight - % LBW (Hispanic)  \
# 0                                 NaN
# 1                                 NaN
# 2                            5.218855
#
#    Low birthweight - % LBW (Hispanic) 95% CI - Low  \
# 0                                              NaN
# 1                                              NaN
# 2                                              4.0
#
#    Low birthweight - % LBW (Hispanic) 95% CI - High  \
# 0                                               NaN
# 1                                               NaN
# 2                                               6.5
#
#    Low birthweight - % LBW (White)  \
# 0                              NaN
# 1                         7.289433
# 2                         7.665056
#
#    Low birthweight - % LBW (White) 95% CI - Low  \
# 0                                           NaN
# 1                                           6.4
# 2                                           7.2
#
#    Low birthweight - % LBW (White) 95% CI - High  % Smokers  \
# 0                                            NaN  20.927353
# 1                                            8.2  18.081557
# 2                                            8.1  17.489033
#
#    Adult smoking - 95% CI - Low  Adult smoking - 95% CI - High  \
# 0                     19.540394                      22.385367
# 1                     17.452459                      18.690261
# 2                     16.955331                      18.060529
#
#    Adult smoking - Quartile  % Obesity  Adult obesity - 95% CI - Low  \
# 0                       NaN       35.5                           NaN
# 1                       1.0       33.3                          27.5
# 2                       1.0       31.0                          28.2
#
#    Adult obesity - 95% CI - High  Adult obesity - Quartile  \
# 0                            NaN                       NaN
# 1                           39.5                       1.0
# 2                           34.0                       1.0
#
#    Food environment index - Food Environment Index  \
# 0                                              5.8
# 1                                              7.2
# 2                                              8.0
#
#    Food environment index - Quartile  % Phys. Inactive  \
# 0                                NaN              29.8
# 1                                2.0              34.7
# 2                                1.0              26.5
#
#    Physical inactivity - 95% CI - Low  Physical inactivity - 95% CI - High  \
# 0                                 NaN                                  NaN
# 1                                28.9                                 41.1
# 2                                23.7                                 29.1
#
#    Physical inactivity - Quartile  \
# 0                             NaN
# 1                             3.0
# 2                             1.0
#
#    Access to exercise opportunities - % With Access to Exercise Opportunities  \
# 0                                          61.112287
# 1                                          69.130124
# 2                                          73.713549
#
#    Access to exercise opportunities - Quartile  \
# 0                                          NaN
# 1                                          1.0
# 2                                          1.0
#
#    Excessive drinking - % Excessive Drinking  \
# 0                                  13.903515
# 1                                  15.026031
# 2                                  17.958310
#
#    Excessive drinking - 95% CI - Low  Excessive drinking - 95% CI - High  \
# 0                          12.641600                           15.269381
# 1                          14.401736                           15.724677
# 2                          17.349863                           18.590787
#
#    Excessive drinking - Quartile  \
# 0                            NaN
# 1                            4.0
# 2                            4.0
#
#    Alcohol-impaired driving deaths - # Alcohol-Impaired Driving Deaths  \
# 0                                             1284.0
# 1                                               15.0
# 2                                               48.0
#
#    Alcohol-impaired driving deaths - # Driving Deaths  \
# 0                                             4654.0
# 1                                               56.0
# 2                                              156.0
#
#    Alcohol-impaired driving deaths - % Driving Deaths with Alcohol Involvement  \
# 0                                          27.589171
# 1                                          26.785714
# 2                                          30.769231
#
#    Alcohol-impaired driving deaths - 95% CI - Low  \
# 0                                       26.866977
# 1                                       19.846405
# 2                                       26.714426
#
#    Alcohol-impaired driving deaths - 95% CI - High  \
# 0                                        28.315133
# 1                                        34.020895
# 2                                        34.873465
#
#    Alcohol-impaired driving deaths - Quartile  \
# 0                                         NaN
# 1                                         2.0
# 2                                         3.0
#
#    Sexually transmitted infections - # Chlamydia Cases  \
# 0                                            29935.0
# 1                                              226.0
# 2                                              691.0
#
#    Sexually transmitted infections - Chlamydia Rate  \
# 0                                             614.1
# 1                                             407.2
# 2                                             325.0
#
#    Sexually transmitted infections - Quartile  Teen births - Teen Birth Rate  \
# 0                                         NaN                      30.894616
# 1                                         2.0                      25.284927
# 2                                         1.0                      27.880692
#
#    Teen births - 95% CI - Low  Teen births - 95% CI - High  \
# 0                        30.6                         31.2
# 1                        22.6                         28.0
# 2                        26.3                         29.5
#
#    Teen births - Quartile  Teen births - Teen Birth Rate (AIAN)  \
# 0                     NaN                                   NaN
# 1                     1.0                                   NaN
# 2                     1.0                                   NaN
#
#    Teen births - Teen Birth Rate (AIAN) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Teen births - Teen Birth Rate (AIAN) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Teen births - Teen Birth Rate (Asian)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
#
#    Teen births - Teen Birth Rate (Asian) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Teen births - Teen Birth Rate (Asian) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Teen births - Teen Birth Rate (Black)  \
# 0                                    NaN
# 1                              31.380753
# 2                              33.408343
#
#    Teen births - Teen Birth Rate (Black) 95% CI - Low  \
# 0                                                NaN
# 1                                               25.2
# 2                                               28.7
#
#    Teen births - Teen Birth Rate (Black) 95% CI - High  \
# 0                                                NaN
# 1                                               38.6
# 2                                               38.1
#
#    Teen births - Teen Birth Rate (Hispanic)  \
# 0                                       NaN
# 1                                       NaN
# 2                                 45.981951
#
#    Teen births - Teen Birth Rate (Hispanic) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                               37.3
#
#    Teen births - Teen Birth Rate (Hispanic) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                               54.7
#
#    Teen births - Teen Birth Rate (White)  \
# 0                                    NaN
# 1                              24.315488
# 2                              26.415892
#
#    Teen births - Teen Birth Rate (White) 95% CI - Low  \
# 0                                                NaN
# 1                                               21.2
# 2                                               24.7
#
#    Teen births - Teen Birth Rate (White) 95% CI - High  \
# 0                                                NaN
# 1                                               27.4
# 2                                               28.2
#
#    Uninsured - # Uninsured  % Uninsured  Uninsured - 95% CI - Low  \
# 0                 438049.0    11.044783                 10.687336
# 1                   4093.0     8.721686                  7.530197
# 2                  19119.0    11.333404                 10.022766
#
#    Uninsured - 95% CI - High  Uninsured - Quartile  \
# 0                  11.402229                   NaN
# 1                   9.913175                   1.0
# 2                  12.644043                   2.0
#
#    Primary care physicians - # Primary Care Physicians  \
# 0                                             3160.0
# 1                                               25.0
# 2                                              155.0
#
#    Primary care physicians - Primary Care Physicians Rate  \
# 0                                           64.82388
# 1                                           45.04180
# 2                                           72.89727
#
#   Primary care physicians - Primary Care Physicians Ratio  \
# 0                                             1543:1
# 1                                             2220:1
# 2                                             1372:1
#
#    Primary care physicians - Quartile  Dentists - # Dentists  \
# 0                                 NaN                 2355.0
# 1                                 2.0                   18.0
# 2                                 1.0                  108.0
#
#    Dentists - Dentist Rate Dentists - Dentist Ratio  Dentists - Quartile  \
# 0                 48.18049                   2076:1                  NaN
# 1                 32.37352                   3089:1                  2.0
# 2                 49.53629                   2019:1                  1.0
#
#    Mental health providers - # Mental Health Providers  \
# 0                                             4948.0
# 1                                               13.0
# 2                                              210.0
#
#    Mental health providers - Mental Health Provider Rate  \
# 0                                          101.23017
# 1                                           23.38087
# 2                                           96.32055
#
#   Mental health providers - Mental Health Provider Ratio  \
# 0                                              988:1
# 1                                             4277:1
# 2                                             1038:1
#
#    Mental health providers - Quartile  \
# 0                                 NaN
# 1                                 3.0
# 2                                 1.0
#
#    Preventable hospital stays - Preventable Hospitalization Rate  \
# 0                                             5805.0
# 1                                             7108.0
# 2                                             4041.0
#
#    Preventable hospital stays - Quartile  \
# 0                                    NaN
# 1                                    4.0
# 2                                    1.0
#
#    Preventable hospital stays - Preventable Hosp. Rate (AIAN)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Preventable hospital stays - Preventable Hosp. Rate (Asian)  \
# 0                                                NaN
# 1                                                NaN
# 2                                             8863.0
#
#    Preventable hospital stays - Preventable Hosp. Rate (Black)  \
# 0                                                NaN
# 1                                             8464.0
# 2                                             6135.0
#
#    Preventable hospital stays - Preventable Hosp. Rate (Hispanic)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Preventable hospital stays - Preventable Hosp. Rate (White)  \
# 0                                                NaN
# 1                                             6877.0
# 2                                             3975.0
#
#    Mammography screening - % With Annual Mammogram  \
# 0                                             40.0
# 1                                             41.0
# 2                                             43.0
#
#    Mammography screening - Quartile  \
# 0                               NaN
# 1                               2.0
# 2                               1.0
#
#    Mammography screening - % Screened (AIAN)  \
# 0                                        NaN
# 1                                        NaN
# 2                                       36.0
#
#    Mammography screening - % Screened (Asian)  \
# 0                                         NaN
# 1                                         NaN
# 2                                        45.0
#
#    Mammography screening - % Screened (Black)  \
# 0                                         NaN
# 1                                        36.0
# 2                                        36.0
#
#    Mammography screening - % Screened (Hispanic)  \
# 0                                            NaN
# 1                                           36.0
# 2                                           32.0
#
#    Mammography screening - % Screened (White)  \
# 0                                         NaN
# 1                                        42.0
# 2                                        44.0
#
#    Flu vaccinations - % Vaccinated  Flu vaccinations - Quartile  \
# 0                             41.0                          NaN
# 1                             41.0                          2.0
# 2                             44.0                          1.0
#
#    Flu vaccinations - % Vaccinated (AIAN)  \
# 0                                     NaN
# 1                                     NaN
# 2                                    50.0
#
#    Flu vaccinations - % Vaccinated (Asian)  \
# 0                                      NaN
# 1                                     46.0
# 2                                     46.0
#
#    Flu vaccinations - % Vaccinated (Black)  \
# 0                                      NaN
# 1                                     30.0
# 2                                     30.0
#
#    Flu vaccinations - % Vaccinated (Hispanic)  \
# 0                                         NaN
# 1                                        29.0
# 2                                        40.0
#
#    Flu vaccinations - % Vaccinated (White)  \
# 0                                      NaN
# 1                                     43.0
# 2                                     45.0
#
#    High school graduation - Cohort Size  % High School  \
# 0                               54917.0      89.300000
# 1                                 660.0      90.000000
# 2                                2207.0      86.361577
#
#    High school graduation - Quartile  Some college - # Some College  \
# 0                                NaN                         744300
# 1                                3.0                           8953
# 2                                4.0                          32812
#
#    Some college - Population  % Some College  Some college - 95% CI - Low  \
# 0                    1232042       60.411902                    59.839542
# 1                      14438       62.009974                    56.114299
# 2                      48703       67.371620                    63.769965
#
#    Some college - 95% CI - High  Some college - Quartile  \
# 0                     60.984261                      NaN
# 1                     67.905648                      1.0
# 2                     70.973275                      1.0
#
#    Unemployment - # Unemployed  Unemployment - Labor Force  % Unemployed  \
# 0                      86493.0                   2198844.0      3.933567
# 1                        942.0                     25957.0      3.629079
# 2                       3393.0                     93849.0      3.615382
#
#    Unemployment - Quartile  Children in poverty - % Children in Poverty  \
# 0                      NaN                                         23.9
# 1                      1.0                                         19.3
# 2                      1.0                                         13.9
#
#    Children in poverty - 95% CI - Low  Children in poverty - 95% CI - High  \
# 0                           23.065957                            24.734043
# 1                           14.295745                            24.304255
# 2                            9.491489                            18.308511
#
#    Children in poverty - Quartile  \
# 0                             NaN
# 1                             1.0
# 2                             1.0
#
#    Children in poverty - % Children in Poverty (AIAN)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          12.222222
#
#    Children in poverty - % Children in Poverty (Asian)  \
# 0                                                NaN
# 1                                           6.837607
# 2                                                NaN
#
#    Children in poverty - % Children in Poverty (Black)  \
# 0                                                NaN
# 1                                          45.789664
# 2                                          26.866216
#
#    Children in poverty - % Children in Poverty (Hispanic)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          25.887574
#
#    Children in poverty - % Children in Poverty (White)  \
# 0                                                NaN
# 1                                          17.621380
# 2                                          10.599011
#
#    Income inequality - 80th Percentile Income  \
# 0                                     99688.0
# 1                                    110026.0
# 2                                    111447.0
#
#    Income inequality - 20th Percentile Income  \
# 0                                     18948.0
# 1                                     21019.0
# 2                                     25227.0
#
#    Income inequality - Income Ratio  Income inequality - Quartile  \
# 0                          5.261136                           NaN
# 1                          5.234597                           3.0
# 2                          4.417767                           1.0
#
#    Children in single-parent households - # Single-Parent Households  \
# 0                                           406913.0
# 1                                             3495.0
# 2                                            10963.0
#
#    Children in single-parent households - # Households  \
# 0                                          1089671.0
# 1                                            13318.0
# 2                                            45415.0
#
#    Children in single-parent households - % Single-Parent Households  \
# 0                                          37.342739
# 1                                          26.242679
# 2                                          24.139601
#
#    Children in single-parent households - 95% CI - Low  \
# 0                                          36.678386
# 1                                          20.956569
# 2                                          20.998250
#
#    Children in single-parent households - 95% CI - High  \
# 0                                          38.007093
# 1                                          31.528790
# 2                                          27.280953
#
#    Children in single-parent households - Quartile  \
# 0                                              NaN
# 1                                              1.0
# 2                                              1.0
#
#    Social associations - # Associations  \
# 0                                  6031
# 1                                    67
# 2                                   217
#
#    Social associations - Social Association Rate  \
# 0                                      12.371924
# 1                                      12.071202
# 2                                      10.205617
#
#    Social associations - Quartile  \
# 0                             NaN
# 1                             2.0
# 2                             3.0
#
#    Violent crime - Annual Average Violent Crimes  \
# 0                                        23306.5
# 1                                          148.5
# 2                                          408.0
#
#    Violent crime - Violent Crime Rate  Violent crime - Quartile  \
# 0                          479.919182                       NaN
# 1                          272.282220                       2.0
# 2                          203.660396                       1.0
#
#    Injury deaths - # Injury Deaths  Injury deaths - Injury Death Rate  \
# 0                          20015.0                          82.250245
# 1                            190.0                          68.526994
# 2                            755.0                          72.385054
#
#    Injury deaths - 95% CI - Low  Injury deaths - 95% CI - High  \
# 0                     81.110742                      83.389748
# 1                     58.782912                      78.271077
# 2                     67.221705                      77.548403
#
#    Injury deaths - Quartile  Injury deaths - Injury Death Rate (AIAN)  \
# 0                       NaN                                       NaN
# 1                       1.0                                       NaN
# 2                       1.0                                       NaN
#
#    Injury deaths - Injury Death Rate (AIAN) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Injury deaths - Injury Death Rate (AIAN) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Injury deaths - Injury Death Rate (Asian)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#    Injury deaths - Injury Death Rate (Asian) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Injury deaths - Injury Death Rate (Asian) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Injury deaths - Injury Death Rate (Black)  \
# 0                                        NaN
# 1                                  42.480099
# 2                                  41.698449
#
#    Injury deaths - Injury Death Rate (Black) 95% CI - Low  \
# 0                                                NaN
# 1                                          26.928739
# 2                                          29.923527
#
#    Injury deaths - Injury Death Rate (Black) 95% CI - High  \
# 0                                                NaN
# 1                                          63.741006
# 2                                          56.568655
#
#    Injury deaths - Injury Death Rate (Hispanic)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
#    Injury deaths - Injury Death Rate (Hispanic) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Injury deaths - Injury Death Rate (Hispanic) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Injury deaths - Injury Death Rate (White)  \
# 0                                        NaN
# 1                                  77.052229
# 2                                  80.040408
#
#    Injury deaths - Injury Death Rate (White) 95% CI - Low  \
# 0                                                NaN
# 1                                          65.186791
# 2                                          74.119384
#
#    Injury deaths - Injury Death Rate (White) 95% CI - High  \
# 0                                                NaN
# 1                                          88.917667
# 2                                          85.961432
#
#    Air pollution - particulate matter - Average Daily PM2.5  \
# 0                                               11.0
# 1                                               11.7
# 2                                               10.3
#
#    Air pollution - particulate matter - Quartile  \
# 0                                            NaN
# 1                                            4.0
# 2                                            1.0
#
#   Drinking water violations - Presence of Water Violation  \
# 0                                                NaN
# 1                                                 No
# 2                                                 No
#
#    Drinking water violations - Quartile  \
# 0                                   NaN
# 1                                   1.0
# 2                                   1.0
#
#    Severe housing problems - % Severe Housing Problems  \
# 0                                          14.340702
# 1                                          14.663462
# 2                                          13.566201
#
#    Severe housing problems - 95% CI - Low  \
# 0                               14.105816
# 1                               11.938795
# 2                               12.344882
#
#    Severe housing problems - 95% CI - High  \
# 0                                14.575589
# 1                                17.388128
# 2                                14.787519
#
#    Severe housing problems - Severe Housing Cost Burden  \
# 0                                                NaN
# 1                                          12.826718
# 2                                          12.277388
#
#    Severe housing problems - Severe Housing Cost Burden 95% CI - Low  \
# 0                                                NaN
# 1                                          10.246232
# 2                                          11.006769
#
#    Severe housing problems - Severe Housing Cost Burden 95% CI - High  \
# 0                                                NaN
# 1                                          15.407204
# 2                                          13.548007
#
#    Severe housing problems - Overcrowding  \
# 0                                     NaN
# 1                                1.201923
# 2                                1.270792
#
#    Severe housing problems - Overcrowding 95% CI - Low  \
# 0                                                NaN
# 1                                           0.573561
# 2                                           0.914724
#
#    Severe housing problems - Overcrowding 95% CI - High  \
# 0                                                NaN
# 1                                           1.830286
# 2                                           1.626860
#
#    Severe housing problems - Inadequate Facilities  \
# 0                                              NaN
# 1                                         1.346154
# 2                                         0.479042
#
#    Severe housing problems - Inadequate Facilities 95% CI - Low  \
# 0                                                NaN
# 1                                           0.455366
# 2                                           0.274920
#
#    Severe housing problems - Inadequate Facilities 95% CI - High  \
# 0                                                NaN
# 1                                           2.236942
# 2                                           0.683164
#
#    Severe housing problems - Quartile  \
# 0                                 NaN
# 1                                 3.0
# 2                                 3.0
#
#    Driving alone to work - % Drive Alone to Work  \
# 0                                      85.794745
# 1                                      86.523661
# 2                                      84.282433
#
#    Driving alone to work - 95% CI - Low  \
# 0                             85.513444
# 1                             85.202456
# 2                             82.603494
#
#    Driving alone to work - 95% CI - High  Driving alone to work - Quartile  \
# 0                              86.076045                               NaN
# 1                              87.844867                               3.0
# 2                              85.961372                               2.0
#
#    Driving alone to work - % Drive Alone (AIAN)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
#    Driving alone to work - % Drive Alone (AIAN) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Driving alone to work - % Drive Alone (AIAN) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Driving alone to work - % Drive Alone (Asian)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    Driving alone to work - % Drive Alone (Asian) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Driving alone to work - % Drive Alone (Asian) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Driving alone to work - % Drive Alone (Black)  \
# 0                                            NaN
# 1                                      82.493738
# 2                                      86.988670
#
#    Driving alone to work - % Drive Alone (Black) 95% CI - Low  \
# 0                                                NaN
# 1                                          75.568960
# 2                                          82.579218
#
#    Driving alone to work - % Drive Alone (Black) 95% CI - High  \
# 0                                                NaN
# 1                                          89.418516
# 2                                          91.398122
#
#    Driving alone to work - % Drive Alone (Hispanic)  \
# 0                                               NaN
# 1                                               NaN
# 2                                         68.296995
#
#    Driving alone to work - % Drive Alone (Hispanic) 95% CI - Low  \
# 0                                                NaN
# 1                                                NaN
# 2                                          55.883815
#
#    Driving alone to work - % Drive Alone (Hispanic) 95% CI - High  \
# 0                                                NaN
# 1                                                NaN
# 2                                          80.710174
#
#    Driving alone to work - % Drive Alone (White)  \
# 0                                            NaN
# 1                                      84.485007
# 2                                      82.952453
#
#    Driving alone to work - % Drive Alone (White) 95% CI - Low  \
# 0                                                NaN
# 1                                          79.745617
# 2                                          80.972009
#
#    Driving alone to work - % Drive Alone (White) 95% CI - High  \
# 0                                                NaN
# 1                                          89.224396
# 2                                          84.932896
#
#    Long commute - driving alone - # Workers who Drive Alone  \
# 0                                          2051445.0
# 1                                            24428.0
# 2                                            91420.0
#
#    Long commute - driving alone - % Long Commute - Drives Alone  \
# 0                                               34.3
# 1                                               39.6
# 2                                               41.7
#
#    Long commute - driving alone - 95% CI - Low  \
# 0                                    33.923218
# 1                                    35.845390
# 2                                    39.065219
#
#    Long commute - driving alone - 95% CI - High  \
# 0                                     34.676782
# 1                                     43.354610
# 2                                     44.334781
#
#    Long commute - driving alone - Quartile
# 0                                      NaN
# 1                                      3.0
# 2                                      3.0

# %%
#Add the renamed columns on to the CDC data set based on the FIPS
df_oct = pd.merge(df_oct, df_health[['FIPS','% Obesity','% Smokers','% Phys. Inactive','% Uninsured','% High School','% Some College','% Unemployed']], on='FIPS', how='left')
df_oct.head(3)
# Out:
#   race_ethnicity_combined             current_status cdc_report_dt   sex  \
# 0                       W  Laboratory-confirmed case    2020-08-31  Male
# 1                       W  Laboratory-confirmed case    2020-10-05  Male
# 2                       W  Laboratory-confirmed case    2020-09-15  Male
#
#      onset_dt pos_spec_dt  hosp_yn icu_yn death_yn hc_work_yn pna_yn  \
# 0  2020-08-22         NaN  Missing     No       No         No     No
# 1  2020-09-27  2020-09-29       No     No       No         No     No
# 2  2020-09-02         NaN       No     No       No         No     No
#
#   abxchest_yn acuterespdistress_yn mechvent_yn fever_yn sfever_yn chills_yn  \
# 0          No                   No          No       No       Yes       Yes
# 1          No                   No          No      Yes       Yes       Yes
# 2          No                   No          No      Yes       Yes       Yes
#
#   myalgia_yn runnose_yn sthroat_yn cough_yn sob_yn nauseavomit_yn headache_yn  \
# 0        Yes         No         No       No     No            Yes         Yes
# 1         No        Yes        Yes      Yes     No             No         Yes
# 2        Yes         No         No      Yes     No             No         Yes
#
#   abdom_yn diarrhea_yn medcond_yn     FIPS res_county res_state  \
# 0       No          No        Yes  39003.0      ALLEN        OH
# 1       No          No         No  39003.0      ALLEN        OH
# 2       No          No         No  39003.0      ALLEN        OH
#
#        age_group  % Obesity  % Smokers  % Phys. Inactive  % Uninsured  \
# 0  40 - 49 Years       34.0  20.184418              27.5     7.696144
# 1  40 - 49 Years       34.0  20.184418              27.5     7.696144
# 2  40 - 49 Years       34.0  20.184418              27.5     7.696144
#
#    % High School  % Some College  % Unemployed
# 0      84.931507        61.94619       4.48647
# 1      84.931507        61.94619       4.48647
# 2      84.931507        61.94619       4.48647

# %%
#Map death_yn to numeric binaries
df_oct['death_yn'] = df_oct['death_yn'].map({'No': 0,'Yes': 1})
df_oct.head(100)
# Out:
#    race_ethnicity_combined             current_status cdc_report_dt   sex  \
# 0                        W  Laboratory-confirmed case    2020-08-31  Male
# 1                        W  Laboratory-confirmed case    2020-10-05  Male
# 2                        W  Laboratory-confirmed case    2020-09-15  Male
# 3                        W  Laboratory-confirmed case    2020-07-06  Male
# 4                        W  Laboratory-confirmed case    2020-08-10  Male
# ..                     ...                        ...           ...   ...
# 95                       W  Laboratory-confirmed case    2020-08-11  Male
# 96                       W  Laboratory-confirmed case    2020-08-05  Male
# 97                       W  Laboratory-confirmed case    2020-09-14  Male
# 98                       W  Laboratory-confirmed case    2020-09-02  Male
# 99                       W  Laboratory-confirmed case    2020-07-01  Male
#
#       onset_dt pos_spec_dt  hosp_yn   icu_yn  death_yn hc_work_yn   pna_yn  \
# 0   2020-08-22         NaN  Missing       No         0         No       No
# 1   2020-09-27  2020-09-29       No       No         0         No       No
# 2   2020-09-02         NaN       No       No         0         No       No
# 3   2020-04-12         NaN      Yes       No         0         No       No
# 4   2020-08-04         NaN       No       No         0         No       No
# ..         ...         ...      ...      ...       ...        ...      ...
# 95  2020-07-31         NaN      Yes  Missing         0    Missing  Missing
# 96  2020-08-02         NaN       No  Missing         0    Missing  Missing
# 97  2020-09-04         NaN       No  Missing         0    Missing  Missing
# 98  2020-08-30         NaN       No  Missing         0    Missing  Missing
# 99         NaN         NaN       No  Missing         0    Missing  Missing
#
#    abxchest_yn acuterespdistress_yn mechvent_yn fever_yn sfever_yn chills_yn  \
# 0           No                   No          No       No       Yes       Yes
# 1           No                   No          No      Yes       Yes       Yes
# 2           No                   No          No      Yes       Yes       Yes
# 3          Yes                   No          No      Yes        No        No
# 4           No                   No          No       No   Unknown       Yes
# ..         ...                  ...         ...      ...       ...       ...
# 95     Missing              Missing     Missing  Missing   Missing   Missing
# 96     Missing              Missing     Missing  Missing   Missing   Missing
# 97     Missing              Missing     Missing  Missing   Missing   Missing
# 98     Missing              Missing     Missing  Missing   Missing   Missing
# 99     Missing              Missing     Missing  Missing   Missing   Missing
#
#    myalgia_yn runnose_yn sthroat_yn cough_yn   sob_yn nauseavomit_yn  \
# 0         Yes         No         No       No       No            Yes
# 1          No        Yes        Yes      Yes       No             No
# 2         Yes         No         No      Yes       No             No
# 3          No         No         No      Yes      Yes             No
# 4          No        Yes        Yes      Yes       No             No
# ..        ...        ...        ...      ...      ...            ...
# 95    Missing    Missing    Missing  Missing  Missing        Missing
# 96    Missing    Missing    Missing  Missing  Missing        Missing
# 97    Missing    Missing    Missing  Missing  Missing        Missing
# 98    Missing    Missing    Missing  Missing  Missing        Missing
# 99    Missing    Missing    Missing  Missing  Missing        Missing
#
#    headache_yn abdom_yn diarrhea_yn medcond_yn     FIPS res_county res_state  \
# 0          Yes       No          No        Yes  39003.0      ALLEN        OH
# 1          Yes       No          No         No  39003.0      ALLEN        OH
# 2          Yes       No          No         No  39003.0      ALLEN        OH
# 3           No       No          No        Yes  39003.0      ALLEN        OH
# 4          Yes       No          No        Yes  39003.0      ALLEN        OH
# ..         ...      ...         ...        ...      ...        ...       ...
# 95     Missing  Missing     Missing    Missing  16001.0        Ada        ID
# 96     Missing  Missing     Missing    Missing  16001.0        Ada        ID
# 97     Missing  Missing     Missing    Missing  16001.0        Ada        ID
# 98     Missing  Missing     Missing    Missing  16001.0        Ada        ID
# 99     Missing  Missing     Missing    Missing  16001.0        Ada        ID
#
#         age_group  % Obesity  % Smokers  % Phys. Inactive  % Uninsured  \
# 0   40 - 49 Years       34.0  20.184418              27.5     7.696144
# 1   40 - 49 Years       34.0  20.184418              27.5     7.696144
# 2   40 - 49 Years       34.0  20.184418              27.5     7.696144
# 3   40 - 49 Years       34.0  20.184418              27.5     7.696144
# 4   40 - 49 Years       34.0  20.184418              27.5     7.696144
# ..            ...        ...        ...               ...          ...
# 95  70 - 79 Years       25.6  11.990701              14.9     8.743292
# 96  70 - 79 Years       25.6  11.990701              14.9     8.743292
# 97  70 - 79 Years       25.6  11.990701              14.9     8.743292
# 98  70 - 79 Years       25.6  11.990701              14.9     8.743292
# 99  70 - 79 Years       25.6  11.990701              14.9     8.743292
#
#     % High School  % Some College  % Unemployed
# 0       84.931507       61.946190      4.486470
# 1       84.931507       61.946190      4.486470
# 2       84.931507       61.946190      4.486470
# 3       84.931507       61.946190      4.486470
# 4       84.931507       61.946190      4.486470
# ..            ...             ...           ...
# 95      84.494806       73.771048      2.459871
# 96      84.494806       73.771048      2.459871
# 97      84.494806       73.771048      2.459871
# 98      84.494806       73.771048      2.459871
# 99      84.494806       73.771048      2.459871
#
# [100 rows x 38 columns]

# %%
from scipy import stats

# %%
#df_oct.dtypes

# %%
#uniqueValues = df_oct['% High School'].unique()
#print(uniqueValues)

# %%
#Drop nan values from added columns
df_oct.dropna(subset = ['% Obesity', '% Smokers', '% Phys. Inactive','% Uninsured',
                        '% High School','% Some College','% Unemployed'], inplace=True)

# %%
#Calculate regression between death_yn and socioeconomic factors
lin_reg1 = stats.linregress(x=df_oct["death_yn"], y=df_oct["% Obesity"])
lin_reg2 = stats.linregress(x=df_oct["death_yn"], y=df_oct["% Smokers"])
lin_reg3 = stats.linregress(x=df_oct["death_yn"], y=df_oct["% Phys. Inactive"])
lin_reg4 = stats.linregress(x=df_oct["death_yn"], y=df_oct["% Uninsured"])
lin_reg5 = stats.linregress(x=df_oct["death_yn"], y=df_oct["% High School"])
lin_reg6 = stats.linregress(x=df_oct["death_yn"], y=df_oct["% Some College"])
lin_reg7 = stats.linregress(x=df_oct["death_yn"], y=df_oct["% Unemployed"])
print(lin_reg1[2],";",lin_reg2[2],";",lin_reg3[2],";",lin_reg4[2],";",lin_reg5[2],";",lin_reg6[2],";",lin_reg7[2])
# Out:
# -0.08459854226592793 ; -0.06398524017613383 ; 0.014410677238303301 ; -0.0713606770161389 ; -0.049987534422671315 ; 0.025242602884312675 ; 0.0473538502896234
