# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from yellowbrick.classifier import ClassificationReport

# %%
df = pd.read_csv(r'~/Desktop/covid/COVID_Cases_Restricted_Detailed_12042020.csv')

# %%
df.head(10)
# Out:
#   race_ethnicity_combined             current_status cdc_report_dt     sex  \
# 0                 Unknown  Laboratory-confirmed case    2020-09-15  Female
# 1                 Unknown  Laboratory-confirmed case    2020-09-27  Female
# 2                 Unknown  Laboratory-confirmed case    2020-09-13  Female
# 3                 Unknown  Laboratory-confirmed case    2020-07-31  Female
# 4                 Unknown  Laboratory-confirmed case    2020-10-01  Female
# 5                 Unknown  Laboratory-confirmed case    2020-10-08  Female
# 6                 Unknown  Laboratory-confirmed case    2020-10-11  Female
# 7                     NaN  Laboratory-confirmed case    2020-08-17     NaN
# 8                     NaN              Probable Case    2020-10-30     NaN
# 9                     NaN  Laboratory-confirmed case    2020-08-16     NaN
#
#      onset_dt pos_spec_dt  hosp_yn   icu_yn death_yn hc_work_yn  ...   sob_yn  \
# 0         NaN         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 1         NaN         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 2         NaN         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 3         NaN         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 4         NaN         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 5         NaN         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 6         NaN         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 7  2020-07-25  2020-07-27      Yes      Yes       No        NaN  ...  Missing
# 8         NaN  2020-10-26  Missing  Missing  Missing        NaN  ...  Missing
# 9         NaN         NaN  Missing  Missing  Missing        NaN  ...  Missing
#
#   nauseavomit_yn headache_yn abdom_yn diarrhea_yn medcond_yn county_fips_code  \
# 0        Missing     Missing  Missing     Missing    Missing          72005.0
# 1        Missing     Missing  Missing     Missing    Missing          72005.0
# 2        Missing     Missing  Missing     Missing    Missing          72005.0
# 3        Missing     Missing  Missing     Missing    Missing          72005.0
# 4        Missing     Missing  Missing     Missing    Missing          72005.0
# 5        Missing     Missing  Missing     Missing    Missing          72005.0
# 6        Missing     Missing  Missing     Missing    Missing          72005.0
# 7            Yes         Yes  Missing         Yes        Yes          72005.0
# 8        Missing     Missing  Missing     Missing    Missing          72005.0
# 9        Missing     Missing  Missing     Missing    Missing          72005.0
#
#   res_county res_state      age_group
# 0  AGUADILLA        PR  30 - 39 Years
# 1  AGUADILLA        PR  30 - 39 Years
# 2  AGUADILLA        PR  30 - 39 Years
# 3  AGUADILLA        PR  30 - 39 Years
# 4  AGUADILLA        PR  30 - 39 Years
# 5  AGUADILLA        PR  30 - 39 Years
# 6  AGUADILLA        PR  30 - 39 Years
# 7  AGUADILLA        PR  50 - 59 Years
# 8  AGUADILLA        PR  50 - 59 Years
# 9  AGUADILLA        PR  50 - 59 Years
#
# [10 rows x 31 columns]

# %%
df.tail(10)
# Out:
#                              race_ethnicity_combined  \
# 8405069  American Indian/Alaska Native, Non-Hispanic
# 8405070  American Indian/Alaska Native, Non-Hispanic
# 8405071  American Indian/Alaska Native, Non-Hispanic
# 8405072  American Indian/Alaska Native, Non-Hispanic
# 8405073  American Indian/Alaska Native, Non-Hispanic
# 8405074                              Hispanic/Latino
# 8405075                              Hispanic/Latino
# 8405076                              Hispanic/Latino
# 8405077                              Hispanic/Latino
# 8405078                              Hispanic/Latino
#
#                     current_status cdc_report_dt   sex    onset_dt  \
# 8405069  Laboratory-confirmed case    2020-06-09  Male         NaN
# 8405070  Laboratory-confirmed case    2020-06-24  Male         NaN
# 8405071  Laboratory-confirmed case    2020-07-08  Male  2020-06-26
# 8405072  Laboratory-confirmed case    2020-10-17  Male  2020-10-13
# 8405073  Laboratory-confirmed case    2020-06-23  Male         NaN
# 8405074  Laboratory-confirmed case    2020-08-04  Male  2020-07-29
# 8405075  Laboratory-confirmed case    2020-05-31  Male  2020-05-26
# 8405076  Laboratory-confirmed case    2020-07-07  Male         NaN
# 8405077  Laboratory-confirmed case    2020-05-28  Male         NaN
# 8405078  Laboratory-confirmed case    2020-05-28  Male  2020-05-25
#
#         pos_spec_dt  hosp_yn   icu_yn death_yn hc_work_yn  ...   sob_yn  \
# 8405069         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 8405070         NaN      Yes  Missing      Yes    Missing  ...  Missing
# 8405071         NaN       No  Missing       No    Missing  ...  Missing
# 8405072         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 8405073         NaN  Missing  Missing  Missing    Missing  ...  Missing
# 8405074         NaN       No  Missing       No    Missing  ...  Missing
# 8405075         NaN       No  Missing       No    Missing  ...  Missing
# 8405076         NaN  Missing  Missing       No    Missing  ...  Missing
# 8405077         NaN       No  Missing       No    Missing  ...  Missing
# 8405078         NaN       No  Missing       No    Missing  ...  Missing
#
#         nauseavomit_yn headache_yn abdom_yn diarrhea_yn medcond_yn  \
# 8405069        Missing     Missing  Missing     Missing    Missing
# 8405070        Missing     Missing  Missing     Missing    Missing
# 8405071        Missing     Missing  Missing     Missing    Missing
# 8405072        Missing     Missing  Missing     Missing    Missing
# 8405073        Missing     Missing  Missing     Missing    Missing
# 8405074        Missing     Missing  Missing     Missing    Missing
# 8405075        Missing     Missing  Missing     Missing    Missing
# 8405076        Missing     Missing  Missing     Missing    Missing
# 8405077        Missing     Missing  Missing     Missing    Missing
# 8405078        Missing     Missing  Missing     Missing    Missing
#
#         county_fips_code res_county res_state      age_group
# 8405069           4027.0       Yuma        AZ  50 - 59 Years
# 8405070           4027.0       Yuma        AZ  50 - 59 Years
# 8405071           4027.0       Yuma        AZ  50 - 59 Years
# 8405072           4027.0       Yuma        AZ  50 - 59 Years
# 8405073           4027.0       Yuma        AZ  50 - 59 Years
# 8405074           8125.0       Yuma        CO  10 - 19 Years
# 8405075           8125.0       Yuma        CO  10 - 19 Years
# 8405076           8125.0       Yuma        CO  10 - 19 Years
# 8405077           8125.0       Yuma        CO  10 - 19 Years
# 8405078           8125.0       Yuma        CO  10 - 19 Years
#
# [10 rows x 31 columns]

# %%
df.drop(['race_ethnicity_combined','current_status', 'cdc_report_dt', 'onset_dt', 'pos_spec_dt', 'county_fips_code', 'res_county','res_state', 'age_group','hc_work_yn','pna_yn','abxchest_yn','acuterespdistress_yn','sfever_yn','chills_yn','myalgia_yn','runnose_yn','sthroat_yn','nauseavomit_yn','headache_yn','abdom_yn','diarrhea_yn'],axis ='columns',inplace = True)
df.head()
# Out:
#       sex  hosp_yn   icu_yn death_yn mechvent_yn fever_yn cough_yn   sob_yn  \
# 0  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 1  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 2  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 3  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 4  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
#
#   medcond_yn
# 0    Missing
# 1    Missing
# 2    Missing
# 3    Missing
# 4    Missing

# %%
df.dropna(inplace=True)
df.head()
# Out:
#       sex  hosp_yn   icu_yn death_yn mechvent_yn fever_yn cough_yn   sob_yn  \
# 0  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 1  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 2  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 3  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
# 4  Female  Missing  Missing  Missing     Missing  Missing  Missing  Missing
#
#   medcond_yn
# 0    Missing
# 1    Missing
# 2    Missing
# 3    Missing
# 4    Missing

# %%
df = df.loc[~((df['sex'] == 'Missing')| (df['hosp_yn'] == 'Missing') | (df['icu_yn'] == 'Missing') | (df['death_yn'] == 'Missing') | (df['fever_yn'] == 'Missing')| (df['cough_yn'] == 'Missing')| (df['sob_yn'] == 'Missing')| (df['mechvent_yn'] == 'Missing')| (df['medcond_yn'] == 'Missing')),:]

df.head()
# Out:
#         sex  hosp_yn   icu_yn death_yn mechvent_yn fever_yn cough_yn   sob_yn  \
# 195  Female  Unknown  Unknown  Unknown     Unknown       No  Unknown  Unknown
# 196  Female  Unknown  Unknown  Unknown     Unknown       No  Unknown  Unknown
# 197  Female       No       No       No          No       No       No       No
# 198  Female  Unknown  Unknown  Unknown     Unknown       No  Unknown  Unknown
# 199  Female       No  Unknown       No     Unknown       No       No       No
#
#     medcond_yn
# 195    Unknown
# 196    Unknown
# 197         No
# 198    Unknown
# 199    Unknown

# %%
df = df.loc[~((df['sex'] == 'Unknown') | (df['hosp_yn'] == 'Unknown') |(df['icu_yn'] == 'Unknown') | (df['death_yn'] == 'Unknown') | (df['fever_yn'] == 'Unknown')| (df['cough_yn'] == 'Unknown')| (df['sob_yn'] == 'Unknown')| (df['mechvent_yn'] == 'Unknown')| (df['medcond_yn'] == 'Unknown')),:]

df.head()
# Out:
#         sex hosp_yn icu_yn death_yn mechvent_yn fever_yn cough_yn sob_yn  \
# 197  Female      No     No       No          No       No       No     No
# 208  Female      No     No       No          No      Yes      Yes     No
# 213  Female      No     No       No          No       No       No     No
# 216  Female      No     No       No          No      Yes      Yes     No
# 541  Female      No     No       No          No       No      Yes     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df.shape
# Out:
# (335365, 9)

# %%
df['sex'] = df['sex'].map({'Female': 0,'Male': 1})
df.head()
# Out:
#      sex hosp_yn icu_yn death_yn mechvent_yn fever_yn cough_yn sob_yn  \
# 197    0      No     No       No          No       No       No     No
# 208    0      No     No       No          No      Yes      Yes     No
# 213    0      No     No       No          No       No       No     No
# 216    0      No     No       No          No      Yes      Yes     No
# 541    0      No     No       No          No       No      Yes     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['hosp_yn'] = df['hosp_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn icu_yn death_yn mechvent_yn fever_yn cough_yn sob_yn  \
# 197    0        0     No       No          No       No       No     No
# 208    0        0     No       No          No      Yes      Yes     No
# 213    0        0     No       No          No       No       No     No
# 216    0        0     No       No          No      Yes      Yes     No
# 541    0        0     No       No          No       No      Yes     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['icu_yn'] = df['icu_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn  icu_yn death_yn mechvent_yn fever_yn cough_yn sob_yn  \
# 197    0        0       0       No          No       No       No     No
# 208    0        0       0       No          No      Yes      Yes     No
# 213    0        0       0       No          No       No       No     No
# 216    0        0       0       No          No      Yes      Yes     No
# 541    0        0       0       No          No       No      Yes     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['death_yn'] = df['death_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn  icu_yn  death_yn mechvent_yn fever_yn cough_yn sob_yn  \
# 197    0        0       0         0          No       No       No     No
# 208    0        0       0         0          No      Yes      Yes     No
# 213    0        0       0         0          No       No       No     No
# 216    0        0       0         0          No      Yes      Yes     No
# 541    0        0       0         0          No       No      Yes     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['mechvent_yn'] = df['mechvent_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn  icu_yn  death_yn  mechvent_yn fever_yn cough_yn sob_yn  \
# 197    0        0       0         0            0       No       No     No
# 208    0        0       0         0            0      Yes      Yes     No
# 213    0        0       0         0            0       No       No     No
# 216    0        0       0         0            0      Yes      Yes     No
# 541    0        0       0         0            0       No      Yes     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['fever_yn'] = df['fever_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn  icu_yn  death_yn  mechvent_yn  fever_yn cough_yn sob_yn  \
# 197    0        0       0         0            0         0       No     No
# 208    0        0       0         0            0         1      Yes     No
# 213    0        0       0         0            0         0       No     No
# 216    0        0       0         0            0         1      Yes     No
# 541    0        0       0         0            0         0      Yes     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['cough_yn'] = df['cough_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn  icu_yn  death_yn  mechvent_yn  fever_yn  cough_yn sob_yn  \
# 197    0        0       0         0            0         0         0     No
# 208    0        0       0         0            0         1         1     No
# 213    0        0       0         0            0         0         0     No
# 216    0        0       0         0            0         1         1     No
# 541    0        0       0         0            0         0         1     No
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['sob_yn'] = df['sob_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn  icu_yn  death_yn  mechvent_yn  fever_yn  cough_yn  sob_yn  \
# 197    0        0       0         0            0         0         0       0
# 208    0        0       0         0            0         1         1       0
# 213    0        0       0         0            0         0         0       0
# 216    0        0       0         0            0         1         1       0
# 541    0        0       0         0            0         0         1       0
#
#     medcond_yn
# 197         No
# 208        Yes
# 213         No
# 216         No
# 541        Yes

# %%
df['medcond_yn'] = df['medcond_yn'].map({'No': 0,'Yes': 1})
df.head()
# Out:
#      sex  hosp_yn  icu_yn  death_yn  mechvent_yn  fever_yn  cough_yn  sob_yn  \
# 197    0        0       0         0            0         0         0       0
# 208    0        0       0         0            0         1         1       0
# 213    0        0       0         0            0         0         0       0
# 216    0        0       0         0            0         1         1       0
# 541    0        0       0         0            0         0         1       0
#
#      medcond_yn
# 197           0
# 208           1
# 213           0
# 216           0
# 541           1

# %%
np.any(np.isnan(df))
# Out:
# False

# %%
np.all(np.isfinite(df))
# Out:
# True

# %%
target = df.death_yn
df = df.drop('death_yn',axis = 'columns')

# %%
X_train, X_test, y_train, y_test = train_test_split(df,target,test_size = 0.2)

# %%
len(X_train)
# Out:
# 268292

# %%
len(X_test)
# Out:
# 67073

# %%
len(df)
# Out:
# 335365

# %%
model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.9455965887913169

# %%
target = ['Survived','Died']
visualizer = ClassificationReport(model, classes=target, support=True)
visualizer.fit(X_train, y_train)      
visualizer.score(X_test, y_test)  
visualizer.show()
# Out:
# /Users/yogiandyobi/anaconda3/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# <AxesSubplot:title={'center':'GaussianNB Classification Report'}>

# %%
model = SVC(kernel='linear')

# %%
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
model.score(X_test,y_test)
# Out:
# 0.9686461020082596

# %%
target = ['Survived','Died']
visualizer = ClassificationReport(model, classes=target, support=True)
visualizer.fit(X_train, y_train)      
visualizer.score(X_test, y_test)  
visualizer.show()
# Out:
# /Users/yogiandyobi/anaconda3/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# <AxesSubplot:title={'center':'SVC Classification Report'}>
